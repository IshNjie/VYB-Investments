# %%
import sys
import os

sys.path.append(os.path.abspath("../modules"))

from vyb import StockAnalysis


sx = StockAnalysis("APLD")
# Out:
# Initialized StockAnalysis for APLD with default period '2y'.

# %%
sx.plot_data(moving_window = 30)
# Out:
# Data not loaded. Calling get_data() first...
# Latest close on 2026-05-08: $41.25
# Latest 30-day MA on 2026-05-08: $31.15

# %%
sx.benchmark(["EME", "WULF", "VRT"], period="2y")
# Out:
# Fundamental Comparison - if available:
#   Ticker        P/E    EPS   Beta          Mkt Cap    RSI
# 0    EME  30.958683  29.77  1.169   41,042,997,248  68.46
# 1   WULF        NaN  -2.51  4.284   11,522,728,960  60.48
# 2    VRT  85.419600   3.98  2.099  130,585,468,928  60.72
# 3   APLD        NaN  -0.38  5.700   11,787,993,088  66.99

# %%
sx.benchmark(["^GSPC", "SOXX"], period="2y")
# Out:
# Fundamental Comparison - if available:
#   Ticker  P/E   EPS  Beta           Mkt Cap    RSI
# 2   APLD  NaN -0.38   5.7  11,787,993,088.0  66.99

# %%
sx.earnings_tracker()
# Out:
# Earnings Tracker for APLD (last 12 quarters):
#    Earnings Date  EPS Estimate  Reported EPS   Beat  Surprise %
# 0     2023-04-06         -0.04         -0.01   True       75.00
# 1     2023-07-24         -0.07         -0.01   True       85.71
# 2     2024-01-16          0.01         -0.05  False     -600.00
# 3     2024-04-11         -0.07         -0.24  False     -242.86
# 4     2024-08-28         -0.22         -0.36  False      -63.64
# 5     2024-10-09         -0.26         -0.15   True       42.31
# 6     2025-01-14         -0.14         -0.06   True       57.14
# 7     2025-04-14         -0.10         -0.08   True       20.00
# 8     2025-07-30         -0.21         -0.03   True       85.71
# 9     2025-10-09         -0.15         -0.03   True       80.00
# 10    2026-01-07         -0.12         -0.07   True       41.67
# 11    2026-04-08         -0.21          0.09   True      142.86

# %%
sx.plot_rsi()
# Out:
# Data not loaded. Calling get_data() first...

# %%
income, balance = sx.get_key_financials(quarterly=True)

# %%
income
# Out:
#                        2025-05-31     2025-08-31     2025-11-30     2026-02-28
# Revenue             -33,300,000.0   64,216,000.0  126,589,000.0  126,637,000.0
# Cost_of_Revenue     -61,111,000.0   55,606,000.0  100,553,000.0   72,832,000.0
# Operating_Expenses   16,213,000.0   29,152,000.0   56,993,000.0   79,723,000.0
# Revenue Growth                nan        -292.84          97.13           0.04
# Gross Profit         27,811,000.0    8,610,000.0   26,036,000.0   53,805,000.0
# Gross Margin               -83.52          13.41          20.57          42.49
# Operating Income     11,598,000.0  -20,542,000.0  -30,957,000.0  -25,918,000.0
# Operating Margin           -34.83         -31.99         -24.45         -20.47

# %%
balance
# Out:
#                          2025-05-31      2025-08-31       2025-11-30  \
# Cash                   41,552,000.0    73,911,000.0  1,913,436,000.0
# Total_Debt            702,877,000.0   700,209,000.0  2,608,677,000.0
# Retained_Earnings    -481,055,000.0  -497,981,000.0   -512,380,000.0
# Accounts_Receivable     3,043,000.0    29,134,000.0     13,345,000.0
#
#                           2026-02-28
# Cash                 1,730,440,000.0
# Total_Debt           2,827,480,000.0
# Retained_Earnings     -583,057,000.0
# Accounts_Receivable     20,753,000.0
