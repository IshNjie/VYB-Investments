# %% [markdown]
# # Watches of Switzerland (WOSG)

# %% [markdown]
# ### <u>Company Synopsis</u>
#
# Operates as a retailer of luxury watches and jewelry in the United Kingdom, Europe, and the United States.
#
# As a retailer and distributor, they do not own the watch brands or manufacture the watches. They are referred to as an authorised dealer, officially approved by watch brands to sell its watches. This provides the customer with confidence that the products are authentic and supplied straight from the brand.
#
# As part of the FTSE 250, WOSG have ~3000 employees across their various channels:
# * Watches of Switzerland Flagship stores
# * Mappin & Webb
# * Goldsmiths
# * Mayors
# * Betteridge
# * Deutsch & Deutsch

# %% [markdown]
# ### <u> Brief Swiss Watch Industry Breakdown</u>
#
#
# The Swiss Watch Industry is the world’s elite producer of luxury high end timepieces, known for complex mechanical watches depicting the best in class in engineering, heritage and exclusivity.
#
# **Key Brands:**
#
# - **Conglomerates**: The Swatch Group (owns Omega, Longines, Tissot, and many others - varying in volume across entry/mid tiers) and Richemont (Cartier, IWC, Vacheron Constantin among others).
# - **Independent Brands**: Rolex (by far the largest brand), Patek Philippe, Audemars Piguet, and Richard Mille (who pride on exclusivity).
#
# #### Swiss Made
#
# “Swiss Made” is **legally protected** and tightly regulated by the Swiss government.
#
# ##### Legal requirements
#
# A watch can be labeled *Swiss Made* if:
#
# 1. **The movement is Swiss**
#     - Defined by Swiss law (assembled + inspected in Switzerland)
# 2. **The movement is cased in Switzerland**
#     - Final assembly happens there
# 3. **Final inspection happens in Switzerland**
# 4. **At least 60% of manufacturing cost is Swiss-based**
#
# Meaning that parts can come from outside Switzerland (e.g., cases from Asia), but the value of the cost attributed to Switzerland must be (60%). So the idea of Swiss made is to ensure that the assembly of the watch is done in Switzerland.

# %% [markdown]
# ### <u>Revenue Breakdown</u>
#
#
# | Category              | FY 2022     | FY 2023     | FY 2024     | FY 2025     |
# |----------------------|-------------|-------------|-------------|-------------|
# | Revenue              | 1,238,000.00| 1,542,800.00| 1,537,900.00| 1,651,500.00|
# | Revenue Growth       |             | 24.62%      | -0.32%      | 7.39%       |
# |                      |             |             |             |             |
# | Cost of Revenue      | 1,056,700.00| 1,324,100.00| 1,348,000.00| 1,440,300.00|
# | Gross Profit         | 181,300.00  | 218,700.00  | 189,900.00  | 211,200.00  |
# | Profit Margin        | 14.64%      | 14.18%      | 12.35%      | 12.79%      |
# |                      |             |             |             |             |
# | Operating Expenses   | 37,600.00   | 39,900.00   | 37,500.00   | 43,600.00   |
# | Operating Income     | 143,700.00  | 178,800.00  | 152,400.00  | 167,600.00  |
# | Operating Profit (%) | 11.61%      | 11.59%      | 9.91%       | 10.15%      |

# %%
import sys
import os

sys.path.append(os.path.abspath("../modules"))

from vyb import StockAnalysis


sx = StockAnalysis("WOSG.L")

# %%
sx.plot_data()
# Out:
# Data not loaded. Calling get_data() first...

# %% [markdown]
# The stock price of WOSG is recovering from liberation day, with strong demand from the US. The group reported a 15% increase in sales in the US in H2 [last year](https://www.businessoffashion.com/news/luxury/watches-of-switzerland-sees-15-surge-in-us-sales-on-demand-for-high-end-timepieces/), influenced by the acquisition of Deutsch & Deutsch - a notable jeweller in Texas.

# %%
sx.benchmark(["^FTMC"])
# Out:
# Fundamental Comparison - if available:
#    Ticker        P/E  EPS   Beta          Mkt Cap
# 1  WOSG.L  16.849998  0.3  1.792  1,169,788,160.0

# %% [markdown]
# WOSG seemed to show great growth from April 24 - March 25; then, April 2nd, Trump announced tariffs on all imports from all countries, sending both WOSG and the FTSE 250 into a decline. Post that however, where the FTSE 250 has seen some steady growth, WOSG showed volatility before landing ~30% below the periods high.

# %% [markdown]
# ## Competitors
#
# Watches of Switzerland will compete on multiple levels
#
# ### Luxury Watch Retailers
#
# Other retailers will pose direct competition to WOSG. Bucherer, being a notable one, was acquired by Rolex in 2023. The idea here is to control the delivery of the watches to the consumer. Bucherer and Rolex have previously had a long standing relationship prior to the acquisition, but this just solidifies Rolex’ bid to get closer to their customer.
#
# ### Watch Brands
#
# Though WOSG do not own the watches or manufacture the watches, watch brands could be moving towards opening their own boutiques, and placing exclusive watches within those boutiques. This obviously disadvantages WOSG, as customers will have more choice on their high street to purchase their new [watch.](https://wristbuddys.com/en-gb/blogs/blog/new-strategy-for-rolex-exclusive-boutiques-could-become-a-reality)
#
# ### Others
#
# Second hand markets as well as broader luxury retailers are key competitors for the brand. Chrono24 ensure the availability of watches and luxury jewellers also have the ability to sell watches as well as other items.
