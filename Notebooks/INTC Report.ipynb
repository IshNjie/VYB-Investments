# %%
import sys
import os

sys.path.append(os.path.abspath("../modules"))

from vyb import StockAnalysis


sx = StockAnalysis("INTC")

# %%
sx.plot_data(moving_window = 50)
# Out:
# Data not loaded. Calling get_data() first...

# %%
sx.benchmark(["AMD", "NVDA"], period="2y")
# Out:
# Fundamental Comparison - if available:
#   Ticker         P/E   EPS   Beta            Mkt Cap
# 0    AMD  128.667940  2.62  1.963    549,627,789,312
# 1   NVDA   42.704082  4.90  2.335  5,085,821,140,992
# 2   INTC         NaN -0.60  1.349    476,213,477,376

# %%
sx.benchmark(["^GSPC", "SOXX"], period="2y")
# Out:
# Fundamental Comparison - if available:
#   Ticker  P/E  EPS   Beta            Mkt Cap
# 2   INTC  NaN -0.6  1.349  476,213,477,376.0
