# %%
import sys
import os

sys.path.append(os.path.abspath("../modules"))

from vyb import StockAnalysis


sx = StockAnalysis("INTC")
# Out:
# Initialized StockAnalysis for INTC with default period '2y'.

# %%
sx.plot_data(moving_window = 30)
# Out:
# Data not loaded. Calling get_data() first...
# Latest close on 2026-05-08: $124.92
# Latest 30-day MA on 2026-05-08: $73.36

# %%
sx.benchmark(["AMD", "NVDA"], period="2y")
# Out:
# Fundamental Comparison - if available:
#   Ticker         P/E   EPS   Beta            Mkt Cap    RSI
# 0    AMD  151.730000  3.00  2.399    742,233,079,808  80.73
# 1   NVDA   43.832382  4.91  2.244  5,230,849,163,264  60.35
# 2   INTC         NaN -0.60  2.190    627,722,223,616  88.38

# %%
sx.benchmark(["^GSPC", "SOXX"], period="2y")
# Out:
# Fundamental Comparison - if available:
#   Ticker  P/E  EPS  Beta            Mkt Cap    RSI
# 2   INTC  NaN -0.6  2.19  627,722,223,616.0  88.38

# %%
sx.earnings_tracker()
# Out:
# Earnings Tracker for INTC (last 12 quarters):
#    Earnings Date  EPS Estimate  Reported EPS   Beat  Surprise %
# 0     2023-04-27         -0.14         -0.04   True       71.43
# 1     2023-07-27         -0.03          0.13   True      533.33
# 2     2023-10-26          0.22          0.41   True       86.36
# 3     2024-01-25          0.45          0.54   True       20.00
# 4     2024-04-25          0.14          0.18   True       28.57
# 5     2024-08-01          0.10          0.02  False      -80.00
# 6     2024-10-31         -0.25         -3.88  False    -1452.00
# 7     2025-01-30         -0.22         -0.03   True       86.36
# 8     2025-07-24          0.01         -0.10  False    -1100.00
# 9     2025-10-23          0.01          0.23   True     2200.00
# 10    2026-01-22         -0.09         -0.12  False      -33.33
# 11    2026-04-23          0.01          0.29   True     2800.00

# %%
sx.plot_rsi()
# Out:
# Data not loaded. Calling get_data() first...

# %%
income, balance = sx.get_key_financials()

# %%
income
# Out:
#                           2022-12-31        2023-12-31        2024-12-31  \
# Revenue             63,054,000,000.0  54,228,000,000.0  53,101,000,000.0
# Cost_of_Revenue     36,188,000,000.0  32,517,000,000.0  35,756,000,000.0
# Operating_Expenses  24,530,000,000.0  21,680,000,000.0  22,053,000,000.0
# Revenue Growth                   nan             -14.0             -2.08
# Gross Profit        26,866,000,000.0  21,711,000,000.0  17,345,000,000.0
# Gross Margin                   42.61             40.04             32.66
# Operating Income     2,336,000,000.0      31,000,000.0  -4,708,000,000.0
# Operating Margin                 3.7              0.06             -8.87
#
#                           2025-12-31
# Revenue             52,853,000,000.0
# Cost_of_Revenue     34,478,000,000.0
# Operating_Expenses  18,398,000,000.0
# Revenue Growth                 -0.47
# Gross Profit        18,375,000,000.0
# Gross Margin                   34.77
# Operating Income       -23,000,000.0
# Operating Margin               -0.04

# %%
balance
# Out:
#                            2022-12-31        2023-12-31        2024-12-31  \
# Cash                 11,144,000,000.0   7,079,000,000.0   8,249,000,000.0
# Total_Debt           42,007,000,000.0  49,266,000,000.0  50,011,000,000.0
# Retained_Earnings    70,405,000,000.0  69,156,000,000.0  49,032,000,000.0
# Accounts_Receivable   4,133,000,000.0   3,402,000,000.0   3,478,000,000.0
#
#                            2025-12-31
# Cash                 14,265,000,000.0
# Total_Debt           46,585,000,000.0
# Retained_Earnings    48,983,000,000.0
# Accounts_Receivable   3,839,000,000.0
